# %%
import os
import sys
import csv
import numpy as np
from sklearn import svm
from sklearn.metrics import confusion_matrix as cmat
import collections
import itertools
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report as report  
from sklearn.model_selection import *
from sklearn.feature_selection import *
import matplotlib.pyplot as plt
import time
import random
import numpy
from datetime import datetime
import pandas as pd
import requests
import re
import xarray as xr
import pickle

# %%
directory ='../data/line_p_data/Rosette'
filename = directory+'/'+'cruise-2007-13-station-ros.csv'
#fieldnames = ['Pressure','Temperature','Salinity','Sigma-t','Oxygen_v','Oxygen_m','Fluorescence']

ross_data = pd.DataFrame()

ross_data = pd.read_csv(filename)
ross_data
# Out:
#        TIME        DATE  LATITUDE  LONGITUDE  CTDPRS   CTDTMP   CTDSAL  \
# 0     09:01  01/06/2007  48.57516 -125.49950    12.5  10.9958      NaN
# 1     09:01  01/06/2007  48.57516 -125.49950    12.4  11.0003      NaN
# 2     09:01  01/06/2007  48.57516 -125.49950    12.5  10.9999  31.5060
# 3     09:01  01/06/2007  48.57516 -125.49950     6.3  10.9973  31.5039
# 4     11:45  01/06/2007  48.59967 -126.00100   112.9   6.6316      NaN
# 5     11:45  01/06/2007  48.59967 -126.00100   100.2   6.7009  33.9008
# 6     11:45  01/06/2007  48.59967 -126.00100    76.1   7.4202  33.3080
# 7     11:45  01/06/2007  48.59967 -126.00100    76.3   7.4064  33.3110
# 8     11:45  01/06/2007  48.59967 -126.00100    49.8   8.0805  32.5461
# 9     11:45  01/06/2007  48.59967 -126.00100    26.0   9.5459  31.6501
# 10    11:45  01/06/2007  48.59967 -126.00100    12.0  11.3104  31.3358
# 11    11:45  01/06/2007  48.59967 -126.00100     6.1  11.3338  31.3110
# 12    16:13  01/06/2007  48.64983 -126.66700  1306.8   2.8326  34.4862
# 13    16:13  01/06/2007  48.64983 -126.66700  1250.7   2.9883  34.4659
# 14    16:13  01/06/2007  48.64983 -126.66700  1002.4   3.5110      NaN
# 15    16:13  01/06/2007  48.64983 -126.66700  1002.4   3.5109      NaN
# 16    16:13  01/06/2007  48.64983 -126.66700  1003.4   3.5107  34.3875
# 17    16:13  01/06/2007  48.64983 -126.66700   801.1   4.0032  34.3029
# 18    16:13  01/06/2007  48.64983 -126.66700   601.5   4.5219  34.1905
# 19    16:13  01/06/2007  48.64983 -126.66700   501.2   4.9120      NaN
# 20    16:13  01/06/2007  48.64983 -126.66700   501.8   4.9025      NaN
# 21    16:13  01/06/2007  48.64983 -126.66700   399.6   5.2329  34.0445
# 22    16:13  01/06/2007  48.64983 -126.66700   301.9   5.7320  33.9623
# 23    16:13  01/06/2007  48.64983 -126.66700   250.8   5.7851  33.8842
# 24    16:13  01/06/2007  48.64983 -126.66700   199.7   6.4756  33.8739
# 25    16:13  01/06/2007  48.64983 -126.66700   175.3   6.8217  33.8642
# 26    16:13  01/06/2007  48.64983 -126.66700   151.5   7.0871  33.7737
# 27    16:13  01/06/2007  48.64983 -126.66700   125.1   7.3719  33.4997
# 28    16:13  01/06/2007  48.64983 -126.66700   101.7   7.3110  33.0000
# 29    16:13  01/06/2007  48.64983 -126.66700    76.9   7.2535  32.4860
# ..      ...         ...       ...        ...     ...      ...      ...
# 423   13:47  12/06/2007  50.45067 -145.00150     4.9   6.6914  32.5847
# 24    124.6    47.8    2.36     31.5
# 25    122.8    45.1    2.35     30.7
# 26    136.7    40.1    2.24     29.7
# 27    164.8    32.3    2.02     26.1
# 28    231.9    22.4    1.60     19.1
# 29    293.0    13.9    1.16     11.3
# ..      ...     ...     ...      ...
# 423   308.3    23.8    1.35     13.7
# 424   311.7     NaN     NaN      NaN
# 425   314.6     NaN     NaN      NaN
# 426   315.7     NaN     NaN      NaN
# 427   316.6     NaN     NaN      NaN
# 428   317.8     NaN     NaN      NaN
# 429   148.0   179.8    2.67     36.6
# 430   142.2   173.1    2.68     36.8
# 431   132.4   171.9    2.72     37.5
# 432   114.3   173.7    2.81     38.6
# 433    87.3   176.2    2.94     40.3
# 434    54.6   175.9    3.09     42.4
# 435    21.4   168.0    3.24     44.5
# 436    12.9   159.7    3.28     45.0
# 437    13.9   146.9    3.26     44.7
# 438    21.9   133.4    3.20     43.9
# 439    27.9   117.3    3.15     43.5
# 440    65.5    88.8    2.85     39.8
# 441   104.9    73.1    2.57     35.8
# 442   145.7    60.4    2.30     31.3
# 443   188.8    47.5    1.96     26.6
# 444   208.4    40.8    1.78     24.2
# 445   233.1    34.1    1.63     21.7
# 446   262.8    26.7    1.51     19.1
# 447   308.7    20.1    1.28     12.9
# 448   311.6    19.5    1.27     12.9
# 449   309.9    18.1    1.20     11.6
# 450   305.9    17.9    1.18     11.4
# 451   307.1    18.0    1.18     11.4
# 452   307.9    18.1    1.18     11.4
#
# [453 rows x 11 columns]

# %%
directory = '../data/line_p_data/Rosette'

ross_data = pd.DataFrame()


for filename in os.listdir(directory):
   # print(filename)
    each_data = pd.read_csv(directory+'/'+filename, error_bad_lines=False)
    ross_data = pd.concat([ross_data,each_data],axis=0)

ross_data
# Out:
#        TIME        DATE  LATITUDE  LONGITUDE  CTDPRS  CTDTMP   CTDSAL  OXYGEN  \
# 0     10:21  09/02/2007  48.57583 -125.49966     6.0  8.4299  31.9715   281.6
# 1     12:45  09/02/2007  48.60050 -126.00050     5.8  8.2880  31.8478   280.4
# 2     14:56  09/02/2007  48.62533 -126.33334     4.6  8.3349  31.5109   287.0
# 3     16:48  09/02/2007  48.65033 -126.66700     5.2  8.7896  32.3942   286.5
# 4     18:48  09/02/2007  48.65000 -126.66650     7.8  8.7918      NaN   288.6
# 5     18:48  09/02/2007  48.65000 -126.66650     7.7  8.7917  32.4082   288.6
# 6     18:48  09/02/2007  48.65000 -126.66650     2.2  8.7938      NaN   288.6
# 7     23:00  09/02/2007  48.69100 -127.16534     4.9  8.4059  32.4182   290.8
# 8     02:35  10/02/2007  48.74367 -127.66666     7.2  8.3560  32.4127   291.6
# 9     06:24  10/02/2007  48.77717 -128.17084     2.3  8.2108  32.4009   293.0
# 10    10:12  10/02/2007  48.81650 -128.66684     3.4  8.1030  32.4147   295.3
# 11    13:45  10/02/2007  48.85667 -129.16617     5.2  7.9226  32.4237   292.6
# 12    16:39  10/02/2007  48.89317 -129.66550     5.1  8.2017  32.4476   291.8
# 13    20:07  10/02/2007  48.93333 -130.16701     6.0  8.2174  32.4480   293.3
# 14    23:23  10/02/2007  48.97050 -130.66667     4.6  8.4041      NaN   294.8
# 15    23:23  10/02/2007  48.97050 -130.66667     3.1  8.4056      NaN   294.9
# 496   00:08    27-02-18  49.99933 -144.99950    10.0  5.8992      NaN   311.8
# 497   00:08    27-02-18  49.99933 -144.99950     5.7  5.9030      NaN   311.9
# 498   05:27    27-02-18  49.99900 -144.30350     4.9  6.0100      NaN     NaN
# 499   05:27    27-02-18  49.99900 -144.30350     5.3  6.0104  32.4744     NaN
# 500   02:45    27-02-18  50.14233 -144.83234    10.3  5.8780  32.4936   313.1
# 501   02:45    27-02-18  50.14233 -144.83234     7.4  5.8914  32.4955   313.5
# 502   02:45    27-02-18  50.14233 -144.83234     4.7  5.8798  32.4927   313.8
#
#      SILCAT  PHSPHT  NO2_NO3
# 0     24.70   1.460    16.80
# 1     28.60   1.490    17.30
# 2     26.60   1.360    15.60
# 3     15.50   1.100    11.20
# 4     14.90   1.100    11.40
# 5     15.10   1.100    11.40
# 6     14.90   1.090    11.40
# 7      9.80   1.000     8.60
# 8      8.50   0.950     8.00
# 9     10.30   1.040     9.50
# 10     7.70   0.940     7.90
# 11     7.40   0.970     8.30
# 12     6.40   0.890     7.20
# 13     6.40   0.900     7.20
# 14     6.50   0.890     6.60
# 15     6.70   0.880     6.80
# 16     6.50   0.880     6.90
# 17     6.70   0.880     6.70
# 18     6.20   0.900     6.90
# 19     9.70   1.080     9.70
# 20    12.20   1.140    10.90
# 21    11.70   1.160    11.30
# 22    12.20   1.160    11.10
# 23    12.20   1.150    11.10
# 24    12.50   1.150    10.90
# 25    11.60   1.140    10.70
# 26    11.90   1.150    10.90
# 27    11.60   1.160    10.90
# 28    13.00   1.190    11.40
# 29      NaN     NaN      NaN
# ..      ...     ...      ...
# 473     NaN     NaN      NaN
# 474     NaN     NaN      NaN
# 475   21.45   1.317    14.71
# 476     NaN     NaN      NaN
# 477     NaN     NaN      NaN
# 478     NaN     NaN      NaN
# 479     NaN     NaN      NaN
# 480     NaN     NaN      NaN
# 481     NaN     NaN      NaN
# 482     NaN     NaN      NaN
# 483     NaN     NaN      NaN
# 484     NaN     NaN      NaN
# 485     NaN     NaN      NaN
# 486     NaN     NaN      NaN
# 487     NaN     NaN      NaN
# 488     NaN     NaN      NaN
# 489     NaN     NaN      NaN
# 490     NaN     NaN      NaN
# 491     NaN     NaN      NaN
# 492     NaN     NaN      NaN
# 493     NaN     NaN      NaN
# 494     NaN     NaN      NaN
# 495     NaN     NaN      NaN
# 496     NaN     NaN      NaN
# 497     NaN     NaN      NaN
# 498     NaN     NaN      NaN
# 499   18.76   1.212    13.67
# 500     NaN     NaN      NaN
# 501     NaN     NaN      NaN
# 502     NaN     NaN      NaN
#
# [17578 rows x 11 columns]

# %%
ross_data = ross_data.fillna(-999.0)
ross_data.astype(bool).sum(axis=0)
# Out:
# TIME         17578
# DATE         17578
# LATITUDE     17578
# LONGITUDE    17578
# CTDPRS       17578
# CTDTMP       17578
# CTDSAL       17578
# OXYGEN       17578
# SILCAT       17578
# PHSPHT       17578
# NO2_NO3      17307
# dtype: int64

# %%
ross_data.to_csv(directory+'/'+'papa_data_consolidated.csv',index=False)

# %%
ross_data = ross_data.replace(-999,np.nan)
ross_data = ross_data.replace('-999.0',np.nan,regex=True)
ross_data = ross_data.replace('-999.00',np.nan)
ross_data = ross_data.replace('-999.0000',np.nan)

# %%
ross_data

# %%
 ross_data.count()
